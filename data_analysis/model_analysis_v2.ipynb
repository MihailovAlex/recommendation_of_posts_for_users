# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from catboost import CatBoostClassifier, Pool

from transformers import AutoTokenizer
from transformers import DistilBertModel

# %%
user_data = pd.read_csv('drive//MyDrive//Colab Notebooks//data//users.csv')
user_data.head()
# Out:
#    user_id  gender  age country               city  exp_group       os source
# 0      200       1   34  Russia          Degtyarsk          3  Android    ads
# 1      201       0   37  Russia             Abakan          0  Android    ads
# 2      202       1   17  Russia           Smolensk          4  Android    ads
# 3      203       0   18  Russia             Moscow          1      iOS    ads
# 4      204       0   36  Russia  Anzhero-Sudzhensk          3  Android    ads

# %%
post_data = pd.read_csv('drive//MyDrive//Colab Notebooks//data//posts.csv')
post_data.head()
# Out:
#    post_id                                               text     topic
# 0        1  UK economy facing major risks\n\nThe UK manufa...  business
# 1        2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2        3  Asian quake hits European shares\n\nShares in ...  business
# 3        4  India power shares jump on debut\n\nShares in ...  business
# 4        5  Lacroix label bought by US firm\n\nLuxury good...  business

# %%
feed_data = pd.read_csv('drive//MyDrive//Colab Notebooks//data//feeds.csv')
feed_data.head()
# Out:
#              timestamp  user_id  post_id action  target
# 0  2021-10-14 12:45:21   110257      652   view       0
# 1  2021-10-31 18:54:52     5320     3811   view       0
# 2  2021-11-17 18:21:38   107771     5536   view       0
# 3  2021-11-21 17:02:22    83907     2736   view       0
# 4  2021-10-13 18:35:53      303     6491   view       0

# %% [markdown]
# Поработаем с постами и топиками из таблицы post_data

# %%
from transformers import AutoTokenizer
from transformers import BertModel
from transformers import RobertaModel
from transformers import DistilBertModel


def get_model(model_name):
    assert model_name in ['bert', 'roberta', 'distilbert']

    checkpoint_names = {
        'bert': 'bert-base-cased',
        'roberta': 'roberta-base',
        'distilbert': 'distilbert-base-cased'
    }

    model_classes = {
        'bert': BertModel,
        'roberta': RobertaModel,
        'distilbert': DistilBertModel
    }

    return AutoTokenizer.from_pretrained(checkpoint_names[model_name]), model_classes[model_name].from_pretrained(checkpoint_names[model_name])

# %%
model_name = 'distilbert-base-cased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = DistilBertModel.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]

# %% [markdown]
# Сделаем датасет для постов

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from transformers import DataCollatorWithPadding

class PostDataset(Dataset):
    def __init__(self, texts, tokenizer):
        super().__init__()

        self.texts = tokenizer.batch_encode_plus(
            texts,
            add_special_tokens=True,
            return_token_type_ids=False,
            return_tensors='pt',
            truncation=True,
            padding=True
        )
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        return {'input_ids': self.texts['input_ids'][idx], 'attention_mask': self.texts['attention_mask'][idx]}

    def __len__(self):
        return len(self.texts['input_ids'])


dataset = PostDataset(post_data['text'].values.tolist(), tokenizer)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

loader = DataLoader(dataset, batch_size=32, collate_fn=data_collator, pin_memory=True, shuffle=False)

# %%
import torch
from tqdm import tqdm


@torch.inference_mode()
def get_embeddings_labels(model, loader):
    model.eval()

    total_embeddings = []

    for batch in tqdm(loader):
        batch = {key: batch[key].to(device) for key in ['attention_mask', 'input_ids']}

        embeddings = model(**batch)['last_hidden_state'][:, 0, :]

        total_embeddings.append(embeddings.cpu())

    return torch.cat(total_embeddings, dim=0)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)
print(torch.cuda.get_device_name())

model = model.to(device)
# Out:
# cuda:0
# Tesla T4

# %%
embeddings = get_embeddings_labels(model, loader).numpy()

embeddings
# Out:
# 100%|██████████| 220/220 [01:50<00:00,  1.99it/s]
# array([[ 3.6315086e-01,  4.8937496e-02, -2.6408118e-01, ...,
#         -1.4159346e-01,  1.5918216e-02,  9.1982896e-05],
#        [ 2.3641640e-01, -1.5950108e-01, -3.2779828e-01, ...,
#         -2.8993604e-01,  1.1936528e-01, -1.6235473e-03],
#        [ 3.7519148e-01, -1.1394388e-01, -2.4054705e-01, ...,
#         -3.3891949e-01,  5.8694065e-02, -2.1265799e-02],
#        ...,
#        [ 3.4038273e-01,  6.6492192e-02, -1.6318429e-01, ...,
#         -8.6562753e-02,  2.0340374e-01,  3.2090571e-02],
#        [ 4.3209219e-01,  1.1091532e-02, -1.1730607e-01, ...,
#          7.5401559e-02,  1.0273975e-01,  1.5274222e-02],
#        [ 3.0427766e-01, -7.6215670e-02, -6.7758739e-02, ...,
#         -5.4348916e-02,  2.4438348e-01, -1.4148588e-02]], dtype=float32)

# %%
# кластеризация текстов
from sklearn.decomposition import PCA

centered = embeddings - embeddings.mean()

pca = PCA(n_components=50)
pca_decomp = pca.fit_transform(centered)

# %%
from sklearn.cluster import KMeans

n_clusters = 15

kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(pca_decomp)

post_data['TextCluster'] = kmeans.labels_

dists_columns = [f'DistanceToCluster_{i}' for i in range(n_clusters)]

dists_df = pd.DataFrame(
    data=kmeans.transform(pca_decomp),
    columns=dists_columns
)

dists_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    DistanceToCluster_0  DistanceToCluster_1  DistanceToCluster_2  \
# 0             2.353855             3.625337             3.411175
# 1             2.310817             3.362058             3.221624
# 2             2.386565             3.365002             3.287446
# 3             2.813685             3.798079             3.697577
# 4             2.034604             3.053057             2.846550
#
#    DistanceToCluster_3  DistanceToCluster_4  DistanceToCluster_5  \
# 0             3.371418             2.836325             3.005784
# 1             3.325222             2.560121             2.853049
# 2             3.268210             2.887404             3.039246
# 3             3.513192             3.379107             3.282822
# 4             3.034991             2.144238             2.645245
#
#    DistanceToCluster_6  DistanceToCluster_7  DistanceToCluster_8  \
# 0             3.441464             3.384828             1.809452
# 1             2.978178             3.371665             1.421095
# 2             2.967098             3.499609             1.706188
# 3             3.716256             3.742270             2.469405
# 4             2.639252             2.802445             2.128224
#
#    DistanceToCluster_9  DistanceToCluster_10  DistanceToCluster_11  \
# 0             3.470074              3.459047              2.221048
# 1             3.246447              3.141553              2.239701
# 2             3.393992              3.140520              3.039700
# 3             4.063752              3.793526              3.397228
# 4             3.239778              2.777034              2.935046
#
#    DistanceToCluster_12  DistanceToCluster_13  DistanceToCluster_14
# 0              1.952203              3.420595              3.753656
# 1              2.197514              3.328099              3.553338
# 2              1.823302              3.348239              3.560918
# 3              2.437142              3.730276              2.981264
# 4              1.466523              2.816569              3.332887

# %%
post_data = pd.concat((post_data, dists_df), axis=1)

post_data.drop(["text"], axis=1, inplace=True)

post_data.head()
# Out:
#    post_id     topic  TextCluster  DistanceToCluster_0  DistanceToCluster_1  \
# 0        1  business            8             2.353855             3.625337
# 1        2  business            8             2.310817             3.362058
# 2        3  business            8             2.386565             3.365002
# 3        4  business           12             2.813685             3.798079
# 4        5  business           12             2.034604             3.053057
#
#    DistanceToCluster_2  DistanceToCluster_3  DistanceToCluster_4  \
# 0             3.411175             3.371418             2.836325
# 1             3.221624             3.325222             2.560121
# 2             3.287446             3.268210             2.887404
# 3             3.697577             3.513192             3.379107
# 4             2.846550             3.034991             2.144238
#
#    DistanceToCluster_5  DistanceToCluster_6  DistanceToCluster_7  \
# 0             3.005784             3.441464             3.384828
# 1             2.853049             2.978178             3.371665
# 2             3.039246             2.967098             3.499609
# 3             3.282822             3.716256             3.742270
# 4             2.645245             2.639252             2.802445
#
#    DistanceToCluster_8  DistanceToCluster_9  DistanceToCluster_10  \
# 0             1.809452             3.470074              3.459047
# 1             1.421095             3.246447              3.141553
# 2             1.706188             3.393992              3.140520
# 3             2.469405             4.063752              3.793526
# 4             2.128224             3.239778              2.777034
#
#    DistanceToCluster_11  DistanceToCluster_12  DistanceToCluster_13  \
# 0              2.221048              1.952203              3.420595
# 1              2.239701              2.197514              3.328099
# 2              3.039700              1.823302              3.348239
# 3              3.397228              2.437142              3.730276
# 4              2.935046              1.466523              2.816569
#
#    DistanceToCluster_14
# 0              3.753656
# 1              3.553338
# 2              3.560918
# 3              2.981264
# 4              3.332887

# %%
df = pd.merge(feed_data,
              user_data,
              on='user_id',
              how='left'
             )

# %%
df = pd.merge(df,
             post_data,
             on='post_id',
              how='left'
             )

# %%
df['timestamp'] = pd.to_datetime(df.timestamp)
df['month'] = df['timestamp'].dt.month
df['day'] = df['timestamp'].dt.day

# %%
df = df.drop(['action', 'user_id','post_id', 'timestamp'], axis = 1)

# %%
df.dtypes
# Out:
# timestamp                object
# user_id                   int64
# post_id                   int64
# action                   object
# target                    int64
# gender                    int64
# age                       int64
# country                  object
# city                     object
# exp_group                 int64
# os                       object
# source                   object
# topic                    object
# TextCluster               int32
# DistanceToCluster_0     float32
# DistanceToCluster_1     float32
# DistanceToCluster_2     float32
# DistanceToCluster_3     float32
# DistanceToCluster_4     float32
# DistanceToCluster_5     float32
# DistanceToCluster_6     float32
# DistanceToCluster_7     float32
# DistanceToCluster_8     float32
# DistanceToCluster_9     float32
# DistanceToCluster_10    float32
# DistanceToCluster_11    float32
# DistanceToCluster_12    float32
# DistanceToCluster_13    float32
# DistanceToCluster_14    float32
# dtype: object

# %%
cat_features = list(df.select_dtypes(include=['object']).columns)
cat_features
# Out:
# ['country', 'city', 'os', 'source', 'topic']

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['target'], axis = 1)
y = df.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.columns
# Out:
# Index(['gender', 'age', 'country', 'city', 'exp_group', 'os', 'source',
#        'topic', 'TextCluster', 'DistanceToCluster_0', 'DistanceToCluster_1',
#        'DistanceToCluster_2', 'DistanceToCluster_3', 'DistanceToCluster_4',
#        'DistanceToCluster_5', 'DistanceToCluster_6', 'DistanceToCluster_7',
#        'DistanceToCluster_8', 'DistanceToCluster_9', 'DistanceToCluster_10',
#        'DistanceToCluster_11', 'DistanceToCluster_12', 'DistanceToCluster_13',
#        'DistanceToCluster_14', 'month', 'day'],
#       dtype='object')

# %%
catboost = CatBoostClassifier(
    iterations=500,
    learning_rate=1,
    depth=2,
    random_seed=111,
    thread_count=-1,
    task_type="GPU",
    cat_features=cat_features
)

catboost.fit(X_train, y_train)
# Out:
# 0:	learn: 0.3387840	total: 275ms	remaining: 2m 16s
# 1:	learn: 0.3343532	total: 464ms	remaining: 1m 55s
# 2:	learn: 0.3324897	total: 647ms	remaining: 1m 47s
# 3:	learn: 0.3315867	total: 834ms	remaining: 1m 43s
# 4:	learn: 0.3312603	total: 1.01s	remaining: 1m 39s
# 5:	learn: 0.3311613	total: 1.18s	remaining: 1m 36s
# 6:	learn: 0.3309282	total: 1.38s	remaining: 1m 37s
# 7:	learn: 0.3304090	total: 1.57s	remaining: 1m 36s
# 8:	learn: 0.3303385	total: 1.83s	remaining: 1m 39s
# 9:	learn: 0.3302968	total: 2.1s	remaining: 1m 42s
# 10:	learn: 0.3292041	total: 2.37s	remaining: 1m 45s
# 11:	learn: 0.3291093	total: 2.71s	remaining: 1m 50s
# 12:	learn: 0.3290454	total: 3s	remaining: 1m 52s
# 13:	learn: 0.3289032	total: 3.26s	remaining: 1m 53s
# 14:	learn: 0.3287552	total: 3.45s	remaining: 1m 51s
# 15:	learn: 0.3286732	total: 3.63s	remaining: 1m 49s
# 16:	learn: 0.3284553	total: 3.8s	remaining: 1m 47s
# 17:	learn: 0.3283352	total: 3.97s	remaining: 1m 46s
# 18:	learn: 0.3283185	total: 4.14s	remaining: 1m 44s
# 19:	learn: 0.3282307	total: 4.31s	remaining: 1m 43s
# 20:	learn: 0.3281873	total: 4.48s	remaining: 1m 42s
# 21:	learn: 0.3281630	total: 4.65s	remaining: 1m 41s
# 22:	learn: 0.3281356	total: 4.82s	remaining: 1m 39s
# 23:	learn: 0.3281241	total: 5s	remaining: 1m 39s
# 24:	learn: 0.3279554	total: 5.16s	remaining: 1m 38s
# 25:	learn: 0.3279389	total: 5.33s	remaining: 1m 37s
# 26:	learn: 0.3279192	total: 5.52s	remaining: 1m 36s
# 27:	learn: 0.3278309	total: 5.7s	remaining: 1m 36s
# 28:	learn: 0.3277781	total: 5.86s	remaining: 1m 35s
# 29:	learn: 0.3277394	total: 6.05s	remaining: 1m 34s
# 30:	learn: 0.3277218	total: 6.21s	remaining: 1m 33s
# 31:	learn: 0.3276779	total: 6.38s	remaining: 1m 33s
# 32:	learn: 0.3276024	total: 6.55s	remaining: 1m 32s
# 33:	learn: 0.3275496	total: 6.72s	remaining: 1m 32s
# 34:	learn: 0.3275373	total: 6.89s	remaining: 1m 31s
# 35:	learn: 0.3275116	total: 7.06s	remaining: 1m 31s
# 36:	learn: 0.3274943	total: 7.23s	remaining: 1m 30s
# 37:	learn: 0.3274758	total: 7.4s	remaining: 1m 29s
# 38:	learn: 0.3274475	total: 7.57s	remaining: 1m 29s
# 39:	learn: 0.3274314	total: 7.74s	remaining: 1m 29s
# 40:	learn: 0.3273734	total: 7.91s	remaining: 1m 28s
# 41:	learn: 0.3273545	total: 8.09s	remaining: 1m 28s
# 42:	learn: 0.3273471	total: 8.25s	remaining: 1m 27s
# 43:	learn: 0.3273416	total: 8.42s	remaining: 1m 27s
# 44:	learn: 0.3273371	total: 8.58s	remaining: 1m 26s
# 45:	learn: 0.3272975	total: 8.75s	remaining: 1m 26s
# 46:	learn: 0.3272644	total: 8.93s	remaining: 1m 26s
# 47:	learn: 0.3272547	total: 9.12s	remaining: 1m 25s
# 48:	learn: 0.3272454	total: 9.29s	remaining: 1m 25s
# 49:	learn: 0.3272444	total: 9.45s	remaining: 1m 25s
# 50:	learn: 0.3272258	total: 9.61s	remaining: 1m 24s
# 51:	learn: 0.3272147	total: 9.79s	remaining: 1m 24s
# 52:	learn: 0.3272116	total: 9.97s	remaining: 1m 24s
# 53:	learn: 0.3272091	total: 10.2s	remaining: 1m 23s
# 54:	learn: 0.3271970	total: 10.3s	remaining: 1m 23s
# 55:	learn: 0.3271880	total: 10.5s	remaining: 1m 23s
# 56:	learn: 0.3271741	total: 10.7s	remaining: 1m 22s
# 57:	learn: 0.3271703	total: 10.8s	remaining: 1m 22s
# 58:	learn: 0.3271639	total: 11s	remaining: 1m 22s
# 59:	learn: 0.3271584	total: 11.2s	remaining: 1m 22s
# 60:	learn: 0.3271541	total: 11.4s	remaining: 1m 21s
# 61:	learn: 0.3271140	total: 11.5s	remaining: 1m 21s
# 62:	learn: 0.3271097	total: 11.8s	remaining: 1m 21s
# 63:	learn: 0.3271053	total: 11.9s	remaining: 1m 21s
# 64:	learn: 0.3269752	total: 12.1s	remaining: 1m 20s
# 65:	learn: 0.3269678	total: 12.3s	remaining: 1m 20s
# 66:	learn: 0.3269625	total: 12.4s	remaining: 1m 20s
# 67:	learn: 0.3269491	total: 12.7s	remaining: 1m 20s
# 68:	learn: 0.3269149	total: 12.8s	remaining: 1m 20s
# 69:	learn: 0.3268607	total: 13s	remaining: 1m 19s
# 70:	learn: 0.3268481	total: 13.2s	remaining: 1m 19s
# 71:	learn: 0.3268371	total: 13.4s	remaining: 1m 19s
# 72:	learn: 0.3268353	total: 13.6s	remaining: 1m 19s
# 73:	learn: 0.3268248	total: 13.8s	remaining: 1m 19s
# 74:	learn: 0.3268110	total: 13.9s	remaining: 1m 18s
# 75:	learn: 0.3267602	total: 14.1s	remaining: 1m 18s
# 76:	learn: 0.3267478	total: 14.3s	remaining: 1m 18s
# 77:	learn: 0.3267379	total: 14.5s	remaining: 1m 18s
# 78:	learn: 0.3267351	total: 14.7s	remaining: 1m 18s
# 79:	learn: 0.3267115	total: 14.9s	remaining: 1m 17s
# 80:	learn: 0.3267054	total: 15s	remaining: 1m 17s
# 81:	learn: 0.3266980	total: 15.2s	remaining: 1m 17s
# 82:	learn: 0.3266940	total: 15.4s	remaining: 1m 17s
# 83:	learn: 0.3266900	total: 15.7s	remaining: 1m 17s
# 84:	learn: 0.3266841	total: 15.9s	remaining: 1m 17s
# 85:	learn: 0.3266825	total: 16.2s	remaining: 1m 17s
# 86:	learn: 0.3266746	total: 16.4s	remaining: 1m 17s
# 87:	learn: 0.3266683	total: 16.6s	remaining: 1m 17s
# 88:	learn: 0.3266525	total: 16.9s	remaining: 1m 18s
# 89:	learn: 0.3266487	total: 17.2s	remaining: 1m 18s
# 90:	learn: 0.3266430	total: 17.4s	remaining: 1m 18s
# 91:	learn: 0.3266370	total: 17.7s	remaining: 1m 18s
# 92:	learn: 0.3266324	total: 17.9s	remaining: 1m 18s
# 93:	learn: 0.3266237	total: 18.1s	remaining: 1m 17s
# 94:	learn: 0.3266182	total: 18.2s	remaining: 1m 17s
# 95:	learn: 0.3266143	total: 18.4s	remaining: 1m 17s
# 96:	learn: 0.3266078	total: 18.6s	remaining: 1m 17s
# 97:	learn: 0.3265970	total: 18.7s	remaining: 1m 16s
# 98:	learn: 0.3265927	total: 18.9s	remaining: 1m 16s
# 99:	learn: 0.3265831	total: 19.1s	remaining: 1m 16s
# 100:	learn: 0.3265685	total: 19.3s	remaining: 1m 16s
# 101:	learn: 0.3265599	total: 19.4s	remaining: 1m 15s
# 102:	learn: 0.3265492	total: 19.6s	remaining: 1m 15s
# 103:	learn: 0.3265466	total: 19.8s	remaining: 1m 15s
# 104:	learn: 0.3265407	total: 20s	remaining: 1m 15s
# 105:	learn: 0.3265371	total: 20.1s	remaining: 1m 14s
# 106:	learn: 0.3265306	total: 20.3s	remaining: 1m 14s
# 107:	learn: 0.3265278	total: 20.5s	remaining: 1m 14s
# 108:	learn: 0.3265198	total: 20.7s	remaining: 1m 14s
# 109:	learn: 0.3265201	total: 20.8s	remaining: 1m 13s
# 110:	learn: 0.3265152	total: 21s	remaining: 1m 13s
# 111:	learn: 0.3265063	total: 21.2s	remaining: 1m 13s
# 112:	learn: 0.3265041	total: 21.3s	remaining: 1m 13s
# 113:	learn: 0.3264980	total: 21.5s	remaining: 1m 12s
# 114:	learn: 0.3264918	total: 21.7s	remaining: 1m 12s
# 115:	learn: 0.3264889	total: 21.9s	remaining: 1m 12s
# 116:	learn: 0.3264803	total: 22s	remaining: 1m 12s
# 117:	learn: 0.3264712	total: 22.2s	remaining: 1m 11s
# 118:	learn: 0.3264675	total: 22.4s	remaining: 1m 11s
# 119:	learn: 0.3264627	total: 22.6s	remaining: 1m 11s
# 120:	learn: 0.3264602	total: 22.7s	remaining: 1m 11s
# 121:	learn: 0.3264554	total: 22.9s	remaining: 1m 10s
# 122:	learn: 0.3264276	total: 23.1s	remaining: 1m 10s
# 123:	learn: 0.3264222	total: 23.3s	remaining: 1m 10s
# 124:	learn: 0.3264190	total: 23.4s	remaining: 1m 10s
# 125:	learn: 0.3264072	total: 23.6s	remaining: 1m 10s
# 126:	learn: 0.3264018	total: 23.8s	remaining: 1m 9s
# 127:	learn: 0.3263851	total: 24.1s	remaining: 1m 10s
# 128:	learn: 0.3263697	total: 24.3s	remaining: 1m 9s
# 129:	learn: 0.3263655	total: 24.4s	remaining: 1m 9s
# 130:	learn: 0.3263557	total: 24.6s	remaining: 1m 9s
# 131:	learn: 0.3263449	total: 24.9s	remaining: 1m 9s
# 132:	learn: 0.3263258	total: 25.1s	remaining: 1m 9s
# 133:	learn: 0.3263221	total: 25.3s	remaining: 1m 9s
# 134:	learn: 0.3263199	total: 25.4s	remaining: 1m 8s
# 135:	learn: 0.3263145	total: 25.6s	remaining: 1m 8s
# 136:	learn: 0.3263074	total: 25.9s	remaining: 1m 8s
# 137:	learn: 0.3263062	total: 26.1s	remaining: 1m 8s
# 138:	learn: 0.3263005	total: 26.2s	remaining: 1m 8s
# 139:	learn: 0.3262984	total: 26.4s	remaining: 1m 7s
# 140:	learn: 0.3262922	total: 26.6s	remaining: 1m 7s
# 141:	learn: 0.3262893	total: 26.7s	remaining: 1m 7s
# 142:	learn: 0.3262848	total: 26.9s	remaining: 1m 7s
# 143:	learn: 0.3262735	total: 27.1s	remaining: 1m 6s
# 144:	learn: 0.3262683	total: 27.3s	remaining: 1m 6s
# 145:	learn: 0.3262499	total: 27.6s	remaining: 1m 6s
# 146:	learn: 0.3262476	total: 27.7s	remaining: 1m 6s
# 147:	learn: 0.3262467	total: 27.9s	remaining: 1m 6s
# 148:	learn: 0.3262438	total: 28.1s	remaining: 1m 6s
# 149:	learn: 0.3262253	total: 28.3s	remaining: 1m 6s
# 150:	learn: 0.3262222	total: 28.5s	remaining: 1m 5s
# 151:	learn: 0.3262194	total: 28.8s	remaining: 1m 5s
# 152:	learn: 0.3262155	total: 28.9s	remaining: 1m 5s
# 153:	learn: 0.3262085	total: 29.1s	remaining: 1m 5s
# 154:	learn: 0.3262045	total: 29.3s	remaining: 1m 5s
# 155:	learn: 0.3261965	total: 29.5s	remaining: 1m 5s
# 156:	learn: 0.3261932	total: 29.7s	remaining: 1m 4s
# 157:	learn: 0.3261909	total: 29.9s	remaining: 1m 4s
# 158:	learn: 0.3261870	total: 30.2s	remaining: 1m 4s
# 159:	learn: 0.3261828	total: 30.4s	remaining: 1m 4s
# 160:	learn: 0.3261797	total: 30.6s	remaining: 1m 4s
# 161:	learn: 0.3261770	total: 30.8s	remaining: 1m 4s
# 162:	learn: 0.3261763	total: 31.1s	remaining: 1m 4s
# 163:	learn: 0.3261674	total: 31.3s	remaining: 1m 4s
# 164:	learn: 0.3261640	total: 31.6s	remaining: 1m 4s
# 165:	learn: 0.3261595	total: 31.9s	remaining: 1m 4s
# 166:	learn: 0.3261446	total: 32.2s	remaining: 1m 4s
# 167:	learn: 0.3261423	total: 32.4s	remaining: 1m 3s
# 168:	learn: 0.3261410	total: 32.5s	remaining: 1m 3s
# 169:	learn: 0.3261374	total: 32.7s	remaining: 1m 3s
# 170:	learn: 0.3261257	total: 32.9s	remaining: 1m 3s
# 171:	learn: 0.3261163	total: 33.1s	remaining: 1m 3s
# 172:	learn: 0.3261127	total: 33.2s	remaining: 1m 2s
# 173:	learn: 0.3261028	total: 33.4s	remaining: 1m 2s
# 174:	learn: 0.3261005	total: 33.6s	remaining: 1m 2s
# 175:	learn: 0.3260925	total: 33.8s	remaining: 1m 2s
# 176:	learn: 0.3260896	total: 33.9s	remaining: 1m 1s
# 177:	learn: 0.3260881	total: 34.1s	remaining: 1m 1s
# 178:	learn: 0.3260834	total: 34.3s	remaining: 1m 1s
# 179:	learn: 0.3260796	total: 34.5s	remaining: 1m 1s
# 180:	learn: 0.3260775	total: 34.6s	remaining: 1m 1s
# 181:	learn: 0.3260762	total: 34.8s	remaining: 1m
# 182:	learn: 0.3260735	total: 35s	remaining: 1m
# 183:	learn: 0.3260696	total: 35.1s	remaining: 1m
# 184:	learn: 0.3260681	total: 35.3s	remaining: 1m
# 185:	learn: 0.3260634	total: 35.5s	remaining: 59.9s
# 186:	learn: 0.3260629	total: 35.6s	remaining: 59.6s
# 187:	learn: 0.3260609	total: 35.8s	remaining: 59.4s
# 188:	learn: 0.3260573	total: 36s	remaining: 59.2s
# 189:	learn: 0.3260571	total: 36.1s	remaining: 58.9s
# 190:	learn: 0.3260551	total: 36.3s	remaining: 58.7s
# 191:	learn: 0.3260498	total: 36.5s	remaining: 58.5s
# 192:	learn: 0.3260372	total: 36.6s	remaining: 58.3s
# 193:	learn: 0.3260358	total: 36.8s	remaining: 58.1s
# 194:	learn: 0.3260302	total: 37s	remaining: 57.9s
# 195:	learn: 0.3260296	total: 37.2s	remaining: 57.6s
# 196:	learn: 0.3260269	total: 37.3s	remaining: 57.4s
# 197:	learn: 0.3260254	total: 37.5s	remaining: 57.2s
# 198:	learn: 0.3260250	total: 37.7s	remaining: 57s
# 199:	learn: 0.3260231	total: 37.9s	remaining: 56.8s
# 200:	learn: 0.3260191	total: 38.1s	remaining: 56.6s
# 201:	learn: 0.3260147	total: 38.2s	remaining: 56.4s
# 202:	learn: 0.3260096	total: 38.4s	remaining: 56.2s
# 203:	learn: 0.3260085	total: 38.6s	remaining: 55.9s
# 204:	learn: 0.3260044	total: 38.7s	remaining: 55.7s
# 205:	learn: 0.3260030	total: 38.9s	remaining: 55.5s
# 206:	learn: 0.3259994	total: 39.1s	remaining: 55.3s
# 207:	learn: 0.3259925	total: 39.2s	remaining: 55.1s
# 208:	learn: 0.3259916	total: 39.4s	remaining: 54.8s
# 209:	learn: 0.3259894	total: 39.6s	remaining: 54.6s
# 210:	learn: 0.3259835	total: 39.7s	remaining: 54.4s
# 211:	learn: 0.3259805	total: 39.9s	remaining: 54.2s
# 212:	learn: 0.3259782	total: 40.1s	remaining: 54s
# 213:	learn: 0.3259771	total: 40.2s	remaining: 53.8s
# 214:	learn: 0.3259746	total: 40.4s	remaining: 53.6s
# 215:	learn: 0.3259680	total: 40.6s	remaining: 53.3s
# 216:	learn: 0.3259675	total: 40.8s	remaining: 53.2s
# 217:	learn: 0.3259640	total: 41s	remaining: 53s
# 218:	learn: 0.3259594	total: 41.1s	remaining: 52.8s
# 219:	learn: 0.3259513	total: 41.3s	remaining: 52.6s
# 220:	learn: 0.3259451	total: 41.5s	remaining: 52.4s
# 221:	learn: 0.3259284	total: 41.6s	remaining: 52.1s
# 222:	learn: 0.3259271	total: 41.8s	remaining: 51.9s
# 223:	learn: 0.3259224	total: 42s	remaining: 51.7s
# 224:	learn: 0.3259023	total: 42.1s	remaining: 51.5s
# 225:	learn: 0.3258994	total: 42.3s	remaining: 51.3s
# 226:	learn: 0.3258968	total: 42.6s	remaining: 51.2s
# 227:	learn: 0.3258949	total: 42.8s	remaining: 51.1s
# 228:	learn: 0.3258925	total: 43.1s	remaining: 51s
# 229:	learn: 0.3258904	total: 43.3s	remaining: 50.8s
# 230:	learn: 0.3258871	total: 43.5s	remaining: 50.7s
# 231:	learn: 0.3258846	total: 43.7s	remaining: 50.5s
# 232:	learn: 0.3258796	total: 43.9s	remaining: 50.3s
# 233:	learn: 0.3258760	total: 44.1s	remaining: 50.1s
# 234:	learn: 0.3258677	total: 44.3s	remaining: 49.9s
# 235:	learn: 0.3258645	total: 44.4s	remaining: 49.7s
# 236:	learn: 0.3258564	total: 44.6s	remaining: 49.5s
# 237:	learn: 0.3258539	total: 44.8s	remaining: 49.3s
# 238:	learn: 0.3258516	total: 45s	remaining: 49.1s
# 239:	learn: 0.3258497	total: 45.2s	remaining: 49s
# 240:	learn: 0.3258476	total: 45.4s	remaining: 48.8s
# 241:	learn: 0.3258467	total: 45.6s	remaining: 48.6s
# 242:	learn: 0.3258447	total: 45.8s	remaining: 48.5s
# 243:	learn: 0.3258428	total: 46.1s	remaining: 48.4s
# 244:	learn: 0.3258397	total: 46.4s	remaining: 48.3s
# 245:	learn: 0.3258340	total: 46.6s	remaining: 48.1s
# 246:	learn: 0.3258315	total: 46.7s	remaining: 47.9s
# 247:	learn: 0.3258300	total: 46.9s	remaining: 47.7s
# 248:	learn: 0.3258289	total: 47.1s	remaining: 47.5s
# 249:	learn: 0.3258282	total: 47.3s	remaining: 47.3s
# 250:	learn: 0.3258281	total: 47.5s	remaining: 47.1s
# 251:	learn: 0.3258239	total: 47.6s	remaining: 46.9s
# 252:	learn: 0.3258234	total: 47.8s	remaining: 46.7s
# 253:	learn: 0.3258197	total: 47.9s	remaining: 46.4s
# 254:	learn: 0.3258140	total: 48.1s	remaining: 46.2s
# 255:	learn: 0.3258115	total: 48.3s	remaining: 46s
# 256:	learn: 0.3258070	total: 48.5s	remaining: 45.8s
# 257:	learn: 0.3258055	total: 48.6s	remaining: 45.6s
# 258:	learn: 0.3258049	total: 48.8s	remaining: 45.4s
# 259:	learn: 0.3258044	total: 49s	remaining: 45.2s
# 260:	learn: 0.3258040	total: 49.1s	remaining: 45s
# 261:	learn: 0.3258027	total: 49.3s	remaining: 44.8s
# 262:	learn: 0.3257989	total: 49.5s	remaining: 44.6s
# 263:	learn: 0.3257978	total: 49.6s	remaining: 44.4s
# 264:	learn: 0.3257976	total: 49.9s	remaining: 44.2s
# 265:	learn: 0.3257905	total: 50s	remaining: 44s
# 266:	learn: 0.3257905	total: 50.2s	remaining: 43.8s
# 267:	learn: 0.3257872	total: 50.4s	remaining: 43.6s
# 268:	learn: 0.3257861	total: 50.6s	remaining: 43.4s
# 269:	learn: 0.3257829	total: 50.7s	remaining: 43.2s
# 270:	learn: 0.3257811	total: 50.9s	remaining: 43s
# 271:	learn: 0.3257765	total: 51.1s	remaining: 42.8s
# 272:	learn: 0.3257728	total: 51.3s	remaining: 42.6s
# 273:	learn: 0.3257681	total: 51.4s	remaining: 42.4s
# 274:	learn: 0.3257667	total: 51.6s	remaining: 42.2s
# 275:	learn: 0.3257658	total: 51.8s	remaining: 42s
# 276:	learn: 0.3257644	total: 52s	remaining: 41.9s
# 277:	learn: 0.3257526	total: 52.2s	remaining: 41.7s
# 278:	learn: 0.3257435	total: 52.4s	remaining: 41.5s
# 279:	learn: 0.3257377	total: 52.5s	remaining: 41.3s
# 280:	learn: 0.3257371	total: 52.7s	remaining: 41.1s
# 281:	learn: 0.3257349	total: 52.9s	remaining: 40.9s
# 282:	learn: 0.3257328	total: 53s	remaining: 40.7s
# 283:	learn: 0.3257310	total: 53.2s	remaining: 40.5s
# 284:	learn: 0.3257291	total: 53.4s	remaining: 40.3s
# 285:	learn: 0.3257294	total: 53.5s	remaining: 40.1s
# 286:	learn: 0.3257278	total: 53.7s	remaining: 39.9s
# 287:	learn: 0.3257267	total: 53.9s	remaining: 39.7s
# 288:	learn: 0.3257161	total: 54s	remaining: 39.5s
# 289:	learn: 0.3257157	total: 54.2s	remaining: 39.3s
# 290:	learn: 0.3257143	total: 54.4s	remaining: 39s
# 291:	learn: 0.3257119	total: 54.5s	remaining: 38.8s
# 292:	learn: 0.3257098	total: 54.7s	remaining: 38.6s
# 293:	learn: 0.3257095	total: 54.9s	remaining: 38.4s
# 294:	learn: 0.3257021	total: 55s	remaining: 38.2s
# 295:	learn: 0.3256961	total: 55.2s	remaining: 38s
# 296:	learn: 0.3256944	total: 55.4s	remaining: 37.8s
# 297:	learn: 0.3256926	total: 55.5s	remaining: 37.6s
# 298:	learn: 0.3256933	total: 55.7s	remaining: 37.4s
# 299:	learn: 0.3256894	total: 55.9s	remaining: 37.3s
# 300:	learn: 0.3256882	total: 56.1s	remaining: 37.1s
# 301:	learn: 0.3256865	total: 56.2s	remaining: 36.9s
# 302:	learn: 0.3256772	total: 56.4s	remaining: 36.7s
# 303:	learn: 0.3256762	total: 56.7s	remaining: 36.5s
# 304:	learn: 0.3256759	total: 57s	remaining: 36.4s
# 305:	learn: 0.3256721	total: 57.1s	remaining: 36.2s
# 306:	learn: 0.3256694	total: 57.3s	remaining: 36s
# 307:	learn: 0.3256687	total: 57.5s	remaining: 35.8s
# 308:	learn: 0.3256674	total: 57.7s	remaining: 35.7s
# 309:	learn: 0.3256635	total: 57.9s	remaining: 35.5s
# 310:	learn: 0.3256611	total: 58.1s	remaining: 35.3s
# 311:	learn: 0.3256569	total: 58.4s	remaining: 35.2s
# 312:	learn: 0.3256563	total: 58.6s	remaining: 35s
# 313:	learn: 0.3256562	total: 58.9s	remaining: 34.9s
# 314:	learn: 0.3256521	total: 59.2s	remaining: 34.7s
# 315:	learn: 0.3256518	total: 59.4s	remaining: 34.6s
# 316:	learn: 0.3256490	total: 59.6s	remaining: 34.4s
# 317:	learn: 0.3256473	total: 59.7s	remaining: 34.2s
# 318:	learn: 0.3256466	total: 59.9s	remaining: 34s
# 319:	learn: 0.3256446	total: 1m	remaining: 33.8s
# 320:	learn: 0.3256428	total: 1m	remaining: 33.6s
# 321:	learn: 0.3256403	total: 1m	remaining: 33.4s
# 322:	learn: 0.3256379	total: 1m	remaining: 33.2s
# 323:	learn: 0.3256369	total: 1m	remaining: 33s
# 324:	learn: 0.3256357	total: 1m	remaining: 32.8s
# 325:	learn: 0.3256236	total: 1m 1s	remaining: 32.6s
# 326:	learn: 0.3256224	total: 1m 1s	remaining: 32.4s
# 327:	learn: 0.3256189	total: 1m 1s	remaining: 32.2s
# 328:	learn: 0.3256169	total: 1m 1s	remaining: 32.1s
# 329:	learn: 0.3256159	total: 1m 1s	remaining: 31.9s
# 330:	learn: 0.3256145	total: 1m 2s	remaining: 31.7s
# 331:	learn: 0.3256133	total: 1m 2s	remaining: 31.5s
# 332:	learn: 0.3256124	total: 1m 2s	remaining: 31.3s
# 333:	learn: 0.3256119	total: 1m 2s	remaining: 31.1s
# 334:	learn: 0.3256093	total: 1m 2s	remaining: 30.9s
# 335:	learn: 0.3256085	total: 1m 2s	remaining: 30.7s
# 336:	learn: 0.3256055	total: 1m 2s	remaining: 30.5s
# 337:	learn: 0.3256059	total: 1m 3s	remaining: 30.3s
# 338:	learn: 0.3256026	total: 1m 3s	remaining: 30.1s
# 339:	learn: 0.3256010	total: 1m 3s	remaining: 29.9s
# 340:	learn: 0.3255992	total: 1m 3s	remaining: 29.7s
# 341:	learn: 0.3255966	total: 1m 3s	remaining: 29.5s
# 342:	learn: 0.3255954	total: 1m 4s	remaining: 29.3s
# 343:	learn: 0.3255935	total: 1m 4s	remaining: 29.1s
# 344:	learn: 0.3255914	total: 1m 4s	remaining: 28.9s
# 345:	learn: 0.3255900	total: 1m 4s	remaining: 28.8s
# 346:	learn: 0.3255899	total: 1m 4s	remaining: 28.6s
# 347:	learn: 0.3255890	total: 1m 4s	remaining: 28.4s
# 348:	learn: 0.3255721	total: 1m 5s	remaining: 28.2s
# 349:	learn: 0.3255717	total: 1m 5s	remaining: 28s
# 350:	learn: 0.3255689	total: 1m 5s	remaining: 27.8s
# 351:	learn: 0.3255664	total: 1m 5s	remaining: 27.6s
# 352:	learn: 0.3255638	total: 1m 5s	remaining: 27.4s
# 353:	learn: 0.3255632	total: 1m 5s	remaining: 27.2s
# 354:	learn: 0.3255608	total: 1m 6s	remaining: 27s
# 355:	learn: 0.3255599	total: 1m 6s	remaining: 26.8s
# 356:	learn: 0.3255591	total: 1m 6s	remaining: 26.6s
# 357:	learn: 0.3255599	total: 1m 6s	remaining: 26.4s
# 358:	learn: 0.3255586	total: 1m 6s	remaining: 26.2s
# 359:	learn: 0.3255540	total: 1m 6s	remaining: 26s
# 360:	learn: 0.3255508	total: 1m 7s	remaining: 25.8s
# 361:	learn: 0.3255505	total: 1m 7s	remaining: 25.7s
# 362:	learn: 0.3255481	total: 1m 7s	remaining: 25.5s
# 363:	learn: 0.3255459	total: 1m 7s	remaining: 25.3s
# 364:	learn: 0.3255435	total: 1m 7s	remaining: 25.1s
# 365:	learn: 0.3255422	total: 1m 7s	remaining: 24.9s
# 366:	learn: 0.3255424	total: 1m 8s	remaining: 24.7s
# 367:	learn: 0.3255426	total: 1m 8s	remaining: 24.5s
# 368:	learn: 0.3255405	total: 1m 8s	remaining: 24.3s
# 369:	learn: 0.3255394	total: 1m 8s	remaining: 24.1s
# 370:	learn: 0.3255375	total: 1m 8s	remaining: 23.9s
# 371:	learn: 0.3255366	total: 1m 9s	remaining: 23.8s
# 372:	learn: 0.3255340	total: 1m 9s	remaining: 23.6s
# 373:	learn: 0.3255327	total: 1m 9s	remaining: 23.4s
# 374:	learn: 0.3255304	total: 1m 9s	remaining: 23.2s
# 375:	learn: 0.3255310	total: 1m 9s	remaining: 23s
# 376:	learn: 0.3255279	total: 1m 9s	remaining: 22.8s
# 377:	learn: 0.3255247	total: 1m 10s	remaining: 22.6s
# 378:	learn: 0.3255229	total: 1m 10s	remaining: 22.4s
# 379:	learn: 0.3255200	total: 1m 10s	remaining: 22.2s
# 380:	learn: 0.3255160	total: 1m 10s	remaining: 22s
# 381:	learn: 0.3255111	total: 1m 10s	remaining: 21.8s
# 382:	learn: 0.3255093	total: 1m 10s	remaining: 21.7s
# 383:	learn: 0.3255090	total: 1m 11s	remaining: 21.5s
# 384:	learn: 0.3255073	total: 1m 11s	remaining: 21.3s
# 385:	learn: 0.3255054	total: 1m 11s	remaining: 21.1s
# 386:	learn: 0.3254981	total: 1m 11s	remaining: 21s
# 387:	learn: 0.3254956	total: 1m 11s	remaining: 20.8s
# 388:	learn: 0.3254933	total: 1m 12s	remaining: 20.6s
# 389:	learn: 0.3254903	total: 1m 12s	remaining: 20.4s
# 390:	learn: 0.3254896	total: 1m 12s	remaining: 20.3s
# 391:	learn: 0.3254877	total: 1m 12s	remaining: 20.1s
# 392:	learn: 0.3254785	total: 1m 13s	remaining: 19.9s
# 393:	learn: 0.3254780	total: 1m 13s	remaining: 19.7s
# 394:	learn: 0.3254769	total: 1m 13s	remaining: 19.5s
# 395:	learn: 0.3254761	total: 1m 13s	remaining: 19.4s
# 396:	learn: 0.3254734	total: 1m 13s	remaining: 19.2s
# 397:	learn: 0.3254674	total: 1m 14s	remaining: 19s
# 398:	learn: 0.3254665	total: 1m 14s	remaining: 18.8s
# 399:	learn: 0.3254636	total: 1m 14s	remaining: 18.6s
# 400:	learn: 0.3254631	total: 1m 14s	remaining: 18.4s
# 401:	learn: 0.3254616	total: 1m 14s	remaining: 18.3s
# 402:	learn: 0.3254608	total: 1m 15s	remaining: 18.1s
# 403:	learn: 0.3254590	total: 1m 15s	remaining: 17.9s
# 404:	learn: 0.3254563	total: 1m 15s	remaining: 17.7s
# 405:	learn: 0.3254530	total: 1m 15s	remaining: 17.6s
# 406:	learn: 0.3254518	total: 1m 15s	remaining: 17.4s
# 407:	learn: 0.3254519	total: 1m 16s	remaining: 17.2s
# 408:	learn: 0.3254466	total: 1m 16s	remaining: 17s
# 409:	learn: 0.3254465	total: 1m 16s	remaining: 16.8s
# 410:	learn: 0.3254462	total: 1m 16s	remaining: 16.6s
# 411:	learn: 0.3254454	total: 1m 16s	remaining: 16.4s
# 412:	learn: 0.3254439	total: 1m 17s	remaining: 16.2s
# 413:	learn: 0.3254426	total: 1m 17s	remaining: 16s
# 414:	learn: 0.3254406	total: 1m 17s	remaining: 15.8s
# 415:	learn: 0.3254393	total: 1m 17s	remaining: 15.7s
# 416:	learn: 0.3254383	total: 1m 17s	remaining: 15.5s
# 417:	learn: 0.3254372	total: 1m 17s	remaining: 15.3s
# 418:	learn: 0.3254364	total: 1m 18s	remaining: 15.1s
# 419:	learn: 0.3254349	total: 1m 18s	remaining: 14.9s
# 420:	learn: 0.3254284	total: 1m 18s	remaining: 14.7s
# 421:	learn: 0.3254269	total: 1m 18s	remaining: 14.5s
# 422:	learn: 0.3254216	total: 1m 18s	remaining: 14.3s
# 423:	learn: 0.3254184	total: 1m 18s	remaining: 14.1s
# 424:	learn: 0.3254183	total: 1m 19s	remaining: 13.9s
# 425:	learn: 0.3254174	total: 1m 19s	remaining: 13.8s
# 426:	learn: 0.3254176	total: 1m 19s	remaining: 13.6s
# 427:	learn: 0.3254166	total: 1m 19s	remaining: 13.4s
# 428:	learn: 0.3254135	total: 1m 19s	remaining: 13.2s
# 429:	learn: 0.3254063	total: 1m 19s	remaining: 13s
# 430:	learn: 0.3254057	total: 1m 20s	remaining: 12.8s
# 431:	learn: 0.3254051	total: 1m 20s	remaining: 12.6s
# 432:	learn: 0.3254034	total: 1m 20s	remaining: 12.4s
# 433:	learn: 0.3253990	total: 1m 20s	remaining: 12.3s
# 434:	learn: 0.3253937	total: 1m 20s	remaining: 12.1s
# 435:	learn: 0.3253934	total: 1m 20s	remaining: 11.9s
# 436:	learn: 0.3253861	total: 1m 21s	remaining: 11.7s
# 437:	learn: 0.3253854	total: 1m 21s	remaining: 11.5s
# 438:	learn: 0.3253827	total: 1m 21s	remaining: 11.3s
# 439:	learn: 0.3253809	total: 1m 21s	remaining: 11.1s
# 440:	learn: 0.3253810	total: 1m 21s	remaining: 10.9s
# 441:	learn: 0.3253802	total: 1m 21s	remaining: 10.8s
# 442:	learn: 0.3253707	total: 1m 22s	remaining: 10.6s
# 443:	learn: 0.3253657	total: 1m 22s	remaining: 10.4s
# 444:	learn: 0.3253638	total: 1m 22s	remaining: 10.2s
# 445:	learn: 0.3253622	total: 1m 22s	remaining: 10s
# 446:	learn: 0.3253577	total: 1m 22s	remaining: 9.82s
# 447:	learn: 0.3253554	total: 1m 22s	remaining: 9.63s
# 448:	learn: 0.3253552	total: 1m 23s	remaining: 9.45s
# 449:	learn: 0.3253540	total: 1m 23s	remaining: 9.26s
# 450:	learn: 0.3253525	total: 1m 23s	remaining: 9.07s
# 451:	learn: 0.3253519	total: 1m 23s	remaining: 8.88s
# 452:	learn: 0.3253502	total: 1m 23s	remaining: 8.7s
# 453:	learn: 0.3253496	total: 1m 23s	remaining: 8.51s
# 454:	learn: 0.3253492	total: 1m 24s	remaining: 8.32s
# 455:	learn: 0.3253474	total: 1m 24s	remaining: 8.14s
# 456:	learn: 0.3253293	total: 1m 24s	remaining: 7.95s
# 457:	learn: 0.3253289	total: 1m 24s	remaining: 7.76s
# 458:	learn: 0.3253269	total: 1m 24s	remaining: 7.58s
# 459:	learn: 0.3253269	total: 1m 25s	remaining: 7.39s
# 460:	learn: 0.3253259	total: 1m 25s	remaining: 7.21s
# 461:	learn: 0.3253240	total: 1m 25s	remaining: 7.02s
# 462:	learn: 0.3253226	total: 1m 25s	remaining: 6.83s
# 463:	learn: 0.3253235	total: 1m 25s	remaining: 6.65s
# 464:	learn: 0.3253207	total: 1m 25s	remaining: 6.47s
# 465:	learn: 0.3253142	total: 1m 26s	remaining: 6.28s
# 466:	learn: 0.3253097	total: 1m 26s	remaining: 6.1s
# 467:	learn: 0.3253076	total: 1m 26s	remaining: 5.91s
# 468:	learn: 0.3253073	total: 1m 26s	remaining: 5.73s
# 469:	learn: 0.3253066	total: 1m 26s	remaining: 5.55s
# 470:	learn: 0.3253021	total: 1m 27s	remaining: 5.37s
# 471:	learn: 0.3252994	total: 1m 27s	remaining: 5.18s
# 472:	learn: 0.3252969	total: 1m 27s	remaining: 4.99s
# 473:	learn: 0.3252914	total: 1m 27s	remaining: 4.81s
# 474:	learn: 0.3252896	total: 1m 27s	remaining: 4.62s
# 475:	learn: 0.3252874	total: 1m 27s	remaining: 4.44s
# 476:	learn: 0.3252853	total: 1m 28s	remaining: 4.25s
# 477:	learn: 0.3252844	total: 1m 28s	remaining: 4.07s
# 478:	learn: 0.3252835	total: 1m 28s	remaining: 3.89s
# 479:	learn: 0.3252812	total: 1m 28s	remaining: 3.7s
# 480:	learn: 0.3252801	total: 1m 29s	remaining: 3.52s
# 481:	learn: 0.3252738	total: 1m 29s	remaining: 3.34s
# 482:	learn: 0.3252724	total: 1m 29s	remaining: 3.16s
# 483:	learn: 0.3252697	total: 1m 29s	remaining: 2.97s
# 484:	learn: 0.3252684	total: 1m 30s	remaining: 2.79s
# 485:	learn: 0.3252664	total: 1m 30s	remaining: 2.6s
# 486:	learn: 0.3252658	total: 1m 30s	remaining: 2.41s
# 487:	learn: 0.3252632	total: 1m 30s	remaining: 2.23s
# 488:	learn: 0.3252624	total: 1m 30s	remaining: 2.04s
# 489:	learn: 0.3252594	total: 1m 30s	remaining: 1.86s
# 490:	learn: 0.3252591	total: 1m 31s	remaining: 1.67s
# 491:	learn: 0.3252574	total: 1m 31s	remaining: 1.49s
# 492:	learn: 0.3252572	total: 1m 31s	remaining: 1.3s
# 493:	learn: 0.3252553	total: 1m 31s	remaining: 1.11s
# 494:	learn: 0.3252516	total: 1m 31s	remaining: 928ms
# 495:	learn: 0.3252503	total: 1m 32s	remaining: 742ms
# 496:	learn: 0.3252488	total: 1m 32s	remaining: 557ms
# 497:	learn: 0.3252474	total: 1m 32s	remaining: 371ms
# 498:	learn: 0.3252331	total: 1m 32s	remaining: 186ms
# 499:	learn: 0.3252299	total: 1m 32s	remaining: 0us

# %%
# проверим качество работы модели
pred = catboost.predict(X_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pred_proba = catboost.predict_proba(X_test)
pred_proba = pred_proba[:, 1]

for count, i in enumerate(pred_proba):
    if i>=0.3:
        pred_proba[count] = 1
    else:
        pred_proba[count] = 0

pred_proba
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score

f1_score(y_test, pred), f1_score(y_test, pred_proba)
# Out:
# (1.1361828799963642e-05, 0.006318619762491598)

# %%
accuracy_score(y_test, pred), precision_score(y_test, pred), recall_score(y_test, pred)
# Out:
# (0.8933175757575758, 0.5, 5.680978946292025e-06)

# %%
accuracy_score(y_test, pred_proba), precision_score(y_test, pred_proba), recall_score(y_test, pred_proba)
# Out:
# (0.8924896969696969, 0.22614274258219727, 0.003204072125708702)

# %% [markdown]
# Сравним с работой первой модели для pred_proba
#
# Presicion (0.1859 против 0.2261), recall (0.0004 против 0.0032) и f1_score (0.0008 против 0.0063) показывают большие значения.
#
# Сохраним модель в форматах .cbm и .pkl

# %%
catboost.save_model('catboost_model_v2', format="cbm")

# %%
import pickle
filename = 'sklearn_model_v2.pkl'
pickle.dump(catboost, open(filename, 'wb'))
loaded_model = pickle.load(open(filename, 'rb'))
